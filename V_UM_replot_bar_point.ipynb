# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
import matplotlib.style
import matplotlib as mpl

# %%
df = pd.read_excel('C:/Users/mjc341/desktop/Plotly/PY_2011-17_CRASH.xlsx', sheet = "2011-2018", dtype =object)

# %%
df.columns
# Out:
# Index(['CRASHNUM', 'COUNT', 'DR_AGE', 'DR_GENDER', 'VEH_SPEED', 'Speed_LIMIT',
#        'CALYEAR', 'CRASH_DATE', 'CRASHTIME', 'DAYOFWEEK', 'WEATH', 'LTCOND',
#        'Ped_AGE', 'Ped_GENDER', 'CrashYear', 'Month', 'Holiday', 'Time Range',
#        'LATITUDE', 'LONGITUDE', 'NEIGHBORHOOD'],
#       dtype='object')

# %%
data = VZ[['VEH_SPEED','DAYOFWEEK']]
sns.set_style('darkgrid',{'xtick.color':'.15'})
sns.set_context ('talk')
f,ax =plt.subplots(figsize = (10,5))
m =  sns.barplot(x ='DAYOFWEEK', y ='VEH_SPEED',data = data)
plt.xlabel(" ")
plt.ylabel("Speed")
plt.title('Average Vehicle Speed by Day of Week', loc = 'center', size = 20)
# Out:
# Text(0.5,1,'Average Vehicle Speed by Day of Week')

# %%
sns.palplot(sns.color_palette("muted"))

# %%
sns.palplot(sns.hls_palette(7,l=.5,s=.8))

# %%
sns.palplot(sns.husl_palette(7))

# %%
sns.palplot(sns.color_palette("Set2", 7))

# %%
sns.palplot(sns.color_palette("Paired"))

# %%
data = VZ[['VEH_SPEED','DAYOFWEEK']]
sns.set_style('darkgrid')
sns.set_context ('talk')
sns.set_palette ('muted')
f,ax =plt.subplots(figsize = (10,8))
m =  sns.barplot(x ='DAYOFWEEK', y ='VEH_SPEED',data = data,errwidth = 1.5, capsize = .1)
plt.xlabel(" ")
plt.ylabel("Speed")
plt.xticks(rotation = 75)
plt.title('Average Vehicle Speed by Day of Week', loc = 'center', size = 20)
# Out:
# Text(0.5,1,'Average Vehicle Speed by Day of Week')

# %%
sns.set_style('darkgrid')
sns.set_context ('talk')
sns.set_palette ('muted')
f,ax =plt.subplots(figsize = (10,8))

n =  sns.barplot(x ='Time Range', y ='VEH_SPEED',data = df,errwidth = 1.5, capsize = .1)
plt.xlabel(" ")
plt.ylabel("Speed")
plt.xticks(rotation = 75)
plt.title('Average Vehicle Speed by Time of Day', loc = 'center', size = 20)
# Out:
# Text(0.5,1,'Average Vehicle Speed by Time of Day')

# %%
sns.set_style('darkgrid')
sns.set_context ('talk')
f,ax =plt.subplots(figsize = (10,8))
plt.title("Average Age of Drivers by Gender Across Years", loc='center', size = 20)
pp1 = sns.pointplot(x = 'CALYEAR', y = 'DR_AGE', hue = 'DR_GENDER', data = VZ,
                  palette = {'Male': 'lightcoral', 'Female' :'mediumslateblue', 'n.a.': 'gold'},
                   markers = ['o','^','o'], linestyles = ['-','--','-'],errwidth = 1.5, capsize = .1
                  );
plt.ylabel('Driver Age')
plt.xlabel('Year')
# Out:
# Text(0.5,0,'Year')

# %%
f, ax = plt.subplots(figsize = (10,8))
sns.set_style('darkgrid')
plt.title("Average Vehicle Speed By Gender Across Years", loc='center', size = 20)
pp = sns.pointplot(x = 'CALYEAR', y = 'VEH_SPEED', hue = 'DR_GENDER', data = VZ,
                  palette = {'Male': 'lightcoral', 'Female' :'mediumslateblue', 'n.a.': 'gold'},
                   markers = ['o','^','o'], linestyles = ['-','--','-'],errwidth = 1.5, capsize = .1
                  );
plt.ylabel('Speed')
plt.xlabel('Year')
# Out:
# Text(0.5,0,'Year')

# %%
VZ.columns
# Out:
# Index(['CRASHNUM', 'COUNT', 'DR_AGE', 'DR_GENDER', 'VEH_SPEED', 'Speed_LIMIT',
#        'CALYEAR', 'CRASH_DATE', 'CRASHTIME', 'DAYOFWEEK', 'WEATH', 'LTCOND',
#        'Ped_AGE', 'Ped_GENDER', 'CrashYear', 'Month', 'Holiday', 'Time Range',
#        'LATITUDE', 'LONGITUDE', 'NEIGHBORHOOD'],
#       dtype='object')

# %%
m

# %% [markdown]
# figure = m.get_figure()

# %%
figure = m.get_figure()
figure.savefig('m.png',dpi =400)

# %%
figure = n.get_figure()
figure.savefig('n.png',dpi =400)

# %%
figure = pp.get_figure()
figure.savefig('pp.png',dpi =400)

# %%
figure = pp1.get_figure()
figure.savefig('pp1.png',dpi =400)
