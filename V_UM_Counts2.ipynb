# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
VZ = pd.read_excel('C:/Users/mjc341/desktop/Plotly/PY_GENDER_YR.xlsx', dtype =object)

# %%
VZ.head(3)
# Out:
#     CRASHNUM DR_GENDER CALYEAR       Neighborhood       DAY
# 0  818743120    Female    2011       Coral Gables  Saturday
# 1  818746210      Male    2011       Coral Gables    Friday
# 2  817219810      Male    2011  North Miami Beach    Monday

# %%
f, ax = plt.subplots(figsize = (10,8))
sns.set_style('darkgrid')
p = sns.countplot(x = 'CALYEAR', hue = 'DR_GENDER', data= VZ, palette = 'Set2')

# %%
g = sns.factorplot(x='CALYEAR', hue='DR_GENDER', col='DAY',
                    data=VZ, kind="count",
                   size=4, aspect=.7);

# %%
filter = VZ.filter()

# %%
g2 = sns.factorplot(x='CALYEAR', hue='DAY', col='DR_GENDER',
                    data=VZ, kind="count",
                   size=4, aspect=.7);
