# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
crash1= pd.read_excel('C:/Users/mjc341/Desktop/TESTPY/Neighborhood2.xlsx')

# %%
crash1.columns
# Out:
# Index(['total', '<15', '15-29', '30+', 'neighborhood'], dtype='object')

# %%
sns.set_style('darkgrid')
sns.set_context ('talk')
g3 = sns.PairGrid(crash1, 
                  x_vars = ['total', '<15', '15-29', '30+'], y_vars = ['neighborhood'],size=10, aspect=.25)
g3.map(sns.stripplot, size=10, orient="h",
      color="indigo", edgecolor="floralwhite")
g3.set(xlim=(0, 65), xlabel="", ylabel="")
for ax, title in zip(g3.axes.flat, titles):

    # Set a different title for each axes
    ax.set(title=title)

    # Make the grid horizontal instead of vertical
    ax.xaxis.grid(False)
    ax.yaxis.grid(True)
    
sns.despine(left=True, bottom=True)

# %%
sns.set_style('darkgrid')
#plt.title('Average Vehicle Speed by Day of Week', loc = 'center', size = 20)
with  sns.plotting_context( 'talk' ,font_scale = 1.5):
    g4 = sns.PairGrid(crash1, 
                  x_vars = ['total', '<15', '15-29', '30+'], y_vars = ['neighborhood'],size=10, aspect=.25)
g4.map(sns.stripplot, size=13, orient="h",
      color="indigo", edgecolor="floralwhite")
g4.set(xlim=(0, 65), xlabel="", ylabel="")
# Use semantically meaningful titles for the columns
title = ["Total Crashes", "<15 mph", "15-29 mph", "over 30 mph"]

for ax, title in zip(g3.axes.flat, titles):

    # Set a different title for each axes
    ax.set(title=title)

    # Make the grid horizontal instead of vertical
    ax.xaxis.grid(False)
    ax.yaxis.grid(True)
    
sns.despine(left=True, bottom=True)
