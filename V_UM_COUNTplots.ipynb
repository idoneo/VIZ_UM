# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
VZ = pd.read_excel('C:/Users/mjc341/desktop/Plotly/PY_GENDER_YR.xlsx', dtype =object)

# %%
VZ.head(3)
# Out:
#     CRASHNUM DR_GENDER CALYEAR
# 0  818743120    Female    2011
# 1  817219370      n.a.    2011
# 2  818746210      Male    2011

# %%
c = VZ['CRASHNUM'].value_counts()

# %%
c
# Out:
# 845840380    1
# 835966480    1
# 862266090    1
# 834203500    1
# 915559930    1
# 864228860    1
# 849024510    1
# 843729870    1
# 858330630    1
# 818764310    1
# 840783370    1
# 838604300    1
# 858052110    1
# 824325360    1
# 845829650    1
# 818639190    1
# 827898230    1
# 845813270    1
# 861902360    1
# 869001920    1
# 838587930    1
# 824407590    1
# 863291390    1
# 862901790    1
# 860640800    1
# 839046690    1
# 826742310    1
# 845796910    1
# 863245810    1
# 865310190    1
#             ..
# 840854390    1
# 867101550    1
# 859777900    1
# 858680170    1
# 862268210    1
# 839772980    1
# 828091190    1
# 859754530    1
# 829516600    1
# 834579260    1
# 867252960    1
# 852388670    1
# 845785920    1
# 839019330    1
# 854731590    1
# 856517450    1
# 830008140    1
# 840936270    1
# 868788920    1
# 868969300    1
# 852290390    1
# 844540760    1
# 843508570    1
# 867108930    1
# 821617520    1
# 856501090    1
# 815573860    1
# ...

# %%
f, ax = plt.subplots(figsize = (10,8))
sns.set_style('darkgrid')
pp = sns.countplot(x  = 'DR_GENDER', data= VZ)

# %%
VZ.columns
# Out:
# Index(['CRASHNUM', 'DR_GENDER', 'CALYEAR'], dtype='object')

# %%
f, ax = plt.subplots(figsize = (10,8))
sns.set_style('darkgrid')
pp = sns.countplot(x  = 'DR_GENDER', hue = 'CALYEAR', data= VZ)

# %%
f, ax = plt.subplots(figsize = (10,8))
sns.set_style('darkgrid')
p = sns.countplot(x = 'CALYEAR', hue = 'DR_GENDER', data= VZ)
