# %%
import folium as f
import pandas as pd

# %%
lp = pd.read_excel('C:/Users/mjc341/desktop/Plotly/PY_Lollipop3.xlsx', dtype =object)

# %%
lp.columns
# Out:
# Index(['LAT', 'LONG', 'Name'], dtype='object')

# %%
lp.Name
# Out:
# 0         NW 183Rd St & NW Miami Gardens Dr
# 1                         NW 79th St & Sr 9
# 2                  SR 836 Ext & SR 836 Expy
# 3                 SW 124th Ct & Sw 95th Ter
# 4                  Washington Ave & 13th St
# 5     SR 826 Off Ramp N & Palmetto Off Ramp
# 6                   NW 79th St & Nw 7th Ave
# 7                     SR  A1A & Collins Ave
# 8                 SW 57th Ct & SW 111th Ter
# 9                  NW 183Rd St & NW 2nd Ave
# 10                       S Dixie Hwy & SR 5
# 11                  NE 2nd Ave & NE 79th St
# 12               Palm Springs Mile & SR 932
# 13                 Washington Ave & 14th St
# 14                   W 60th St & W 24th Ave
# 15                 Washington Ave & 15th St
# 16                    67th St & Collins Ave
# 17                       16th St & Alton Rd
# 18                 NW 22nd Ave & Nw 36th St
# Name: Name, dtype: object

# %%
INT = lp['Name'].tolist()
LAT = lp['LAT'].tolist()
LONG = lp['LONG'].tolist()

# %%
INT
# Out:
# ['NW 183Rd St & NW Miami Gardens Dr',
#  'NW 79th St & Sr 9',
#  'SR 836 Ext & SR 836 Expy',
#  'SW 124th Ct & Sw 95th Ter',
#  'Washington Ave & 13th St',
#  'SR 826 Off Ramp N & Palmetto Off Ramp',
#  'NW 79th St & Nw 7th Ave',
#  'SR  A1A & Collins Ave',
#  'SW 57th Ct & SW 111th Ter',
#  'NW 183Rd St & NW 2nd Ave',
#  'S Dixie Hwy & SR 5',
#  'NE 2nd Ave & NE 79th St',
#  'Palm Springs Mile & SR 932',
#  'Washington Ave & 14th St',
#  'W 60th St & W 24th Ave',
#  'Washington Ave & 15th St',
#  '67th St & Collins Ave',
#  '16th St & Alton Rd',
#  'NW 22nd Ave & Nw 36th St']

# %%
LAT
# Out:
# [25.9409581,
#  25.8460544,
#  25.7842455,
#  25.6791168,
#  25.7841886,
#  25.8377571,
#  25.8470466,
#  25.9414436,
#  25.6677583,
#  25.9425595,
#  25.7399358,
#  25.8475892,
#  25.8665956,
#  25.7854331,
#  25.8770333,
#  25.7875727,
#  25.8506061,
#  25.7889038,
#  25.8093352]

# %%
LONG
# Out:
# [-80.2453199,
#  -80.241749,
#  -80.2888777,
#  -80.3967892,
#  -80.1321267,
#  -80.321778,
#  -80.2091276,
#  -80.1212992,
#  -80.2849947,
#  -80.2051932,
#  -80.2378443,
#  -80.1928289,
#  -80.314879,
#  -80.1319534,
#  -80.3313528,
#  -80.131771,
#  -80.1203267,
#  -80.1411626,
#  -80.2320596]

# %%
t_list =['Stamen Terrain','Stamen Toner','Mapbox Bright','cartodbpositron']
miami_center = (25.761681,-80.191788)
m = f.Map(location=miami_center,
         tiles = 'Stamen Toner',
         zoom_start=11)

# %%
for i in range(0,len(lp)):
  f.Marker([lp.iloc[i]['LONG'], lp.iloc[i]['LAT']], popup=lp.iloc[i]['Name'],icon = f.Icon(color= "purple")).add_to(m)
#f.Marker([25.9409581,-80.2453199], popup = 'NW 183Rd St & NW Miami Gardens Dr',icon=f.Icon(color='red')).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
"""f.Marker([25.9409581,-80.2453199], popup = 'NW 183Rd St & NW Miami Gardens Dr',icon=f.Icon(color='red')).add_to(m2)
f.Marker([25.8460544,-80.241749], popup = 'NW 79th St & Sr 9',icon=f.Icon(color='red')).add_to(m2)
f.Marker([25.6790288,-80.3172940], popup = 'SR 836 Ext & SR 836 Expy',icon=f.Icon(color='purple')).add_to(m2)
f.Marker([25.754532,-80.222137], popup = 'SW 124th Ct & Sw 95th Ter',icon=f.Icon(color='purple')).add_to(m2)
f.Marker([25.8310237,-80.2410341], popup = 'Washington Ave & 13th St',icon=f.Icon(color='purple')).add_to(m2)
f.Marker([25.7646847,-80.2552132], popup = 'SR 826 Off Ramp N & Palmetto Off Ramp',icon=f.Icon(color='purple')).add_to(m2)
f.Marker([25.7828841,-80.1311948], popup = 'NW 79th St & Nw 7th Ave',icon=f.Icon(color='blue')).add_to(m2)
f.Marker([25.8459779,-80.2416861], popup = 'SR  A1A & Collins Ave',icon=f.Icon(color='blue')).add_to(m2)
f.Marker([25.9043356,-80.1591017], popup = 'SW 57th Ct & SW 111th Ter',icon=f.Icon(color='blue')).add_to(m2)
f.Marker([25.7952364,-80.2070148], popup = 'NW 183Rd St & NW 2nd Ave',icon=f.Icon(color='blue')).add_to(m2)
m2"""

# %%
data = pd.DataFrame({
    'lat':[25.9409581,
 25.8460544,
 25.7842455,
 25.6791168,
 25.7841886,
 25.8377571,
 25.8470466,
 25.9414436,
 25.6677583,
 25.9425595,
 25.7399358,
 25.8475892,
 25.8665956,
 25.7854331,
 25.8770333,
 25.7875727,
 25.8506061,
 25.7889038,
 25.8093352],
    'lon':[-80.2453199,
 -80.241749,
 -80.2888777,
 -80.3967892,
 -80.1321267,
 -80.321778,
 -80.2091276,
 -80.1212992,
 -80.2849947,
 -80.2051932,
 -80.2378443,
 -80.1928289,
 -80.314879,
 -80.1319534,
 -80.3313528,
 -80.131771,
 -80.1203267,
 -80.1411626,
 -80.2320596],
    'name':['NW 183Rd St & NW Miami Gardens Dr',
 'NW 79th St & Sr 9',
 'SR 836 Ext & SR 836 Expy',
 'SW 124th Ct & Sw 95th Ter',
 'Washington Ave & 13th St',
 'SR 826 Off Ramp N & Palmetto Off Ramp',
 'NW 79th St & Nw 7th Ave',
 'SR  A1A & Collins Ave',
 'SW 57th Ct & SW 111th Ter',
 'NW 183Rd St & NW 2nd Ave',
 'S Dixie Hwy & SR 5',
 'NE 2nd Ave & NE 79th St',
 'Palm Springs Mile & SR 932',
 'Washington Ave & 14th St',
 'W 60th St & W 24th Ave',
 'Washington Ave & 15th St',
 '67th St & Collins Ave',
 '16th St & Alton Rd',
 'NW 22nd Ave & Nw 36th St']
})
data
# Out:
#           lat        lon                                   name
# 0   25.940958 -80.245320      NW 183Rd St & NW Miami Gardens Dr
# 1   25.846054 -80.241749                      NW 79th St & Sr 9
# 2   25.784246 -80.288878               SR 836 Ext & SR 836 Expy
# 3   25.679117 -80.396789              SW 124th Ct & Sw 95th Ter
# 4   25.784189 -80.132127               Washington Ave & 13th St
# 5   25.837757 -80.321778  SR 826 Off Ramp N & Palmetto Off Ramp
# 6   25.847047 -80.209128                NW 79th St & Nw 7th Ave
# 7   25.941444 -80.121299                  SR  A1A & Collins Ave
# 8   25.667758 -80.284995              SW 57th Ct & SW 111th Ter
# 9   25.942560 -80.205193               NW 183Rd St & NW 2nd Ave
# 10  25.739936 -80.237844                     S Dixie Hwy & SR 5
# 11  25.847589 -80.192829                NE 2nd Ave & NE 79th St
# 12  25.866596 -80.314879             Palm Springs Mile & SR 932
# 13  25.785433 -80.131953               Washington Ave & 14th St
# ...

# %%
for i in range(0,len(data)):
 f.Marker([data.iloc[i]['lon'], data.iloc[i]['lat']], popup=data.iloc[i]['name'],icon = f.Icon(color= "purple")).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
t_list =['Stamen Terrain','Stamen Toner','Mapbox Bright','cartodbpositron']
miami_center = (25.761681,-80.191788)
m2 = f.Map(location=miami_center,
         tiles = 'Stamen Toner',
         zoom_start=11)

# %%
f.Marker([25.9409581,-80.2453199], popup = 'NW 183Rd St & NW Miami Gardens Dr',icon=f.Icon(color='purple')).add_to(m2)
f.Marker([25.8460544,-80.241749], popup = 'NW 79th St & Sr 9',icon=f.Icon(color='purple')).add_to(m2)
f.Marker([25.7842455,-80.2888777], popup = 'SR 836 Ext & SR 836 Expy',icon=f.Icon(color='purple')).add_to(m2)
f.Marker([25.6791168,-80.3967892], popup = 'SW 124th Ct & Sw 95th Ter',icon=f.Icon(color='purple')).add_to(m2)
f.Marker([25.7841886,-80.1321267], popup = 'Washington Ave & 13th St',icon=f.Icon(color='purple')).add_to(m2)
f.Marker([25.8377571,-80.321778], popup = 'SR 826 Off Ramp N & Palmetto Off Ramp',icon=f.Icon(color='purple')).add_to(m2)
f.Marker([25.8470466,-80.2091276], popup = 'NW 79th St & NW 7th Ave',icon=f.Icon(color='purple')).add_to(m2)
f.Marker([25.9414436,-80.1212992], popup = 'SR  A1A & Collins Ave',icon=f.Icon(color='purple')).add_to(m2)
f.Marker([25.6677583,-80.2849947], popup = 'SW 57th Ct & SW 111th Ter',icon=f.Icon(color='purple')).add_to(m2)
f.Marker([25.9425595,-80.2051932], popup = 'NW 183Rd St & NW 2nd Ave',icon=f.Icon(color='purple')).add_to(m2)
f.Marker([25.7399358,-80.2378443], popup = 'S Dixie Hwy & SR 5',icon=f.Icon(color='purple')).add_to(m2)
f.Marker([25.8475892,-80.1928289], popup = 'NE 2nd Ave & NE 79th St',icon=f.Icon(color='purple')).add_to(m2)
f.Marker([25.8665956,-80.314879], popup = 'Palm Springs Mile & SR 932',icon=f.Icon(color='purple')).add_to(m2)
f.Marker([25.7854331,-80.1319534], popup = 'Washington Ave & 14th St',icon=f.Icon(color='purple')).add_to(m2)
f.Marker([25.8770333,-80.3313528], popup = 'W 60th St & W 24th Ave',icon=f.Icon(color='purple')).add_to(m2)
f.Marker([25.7875727,-80.131771], popup = 'Washington Ave & 15th St',icon=f.Icon(color='purple')).add_to(m2)
f.Marker([25.8506061,-80.1203267], popup = '67th St & Collins Ave',icon=f.Icon(color='purple')).add_to(m2)
f.Marker([25.7889038,-80.1411626], popup = '16th St & Alton Rd',icon=f.Icon(color='purple')).add_to(m2)
f.Marker([25.8093352,-80.2320596], popup = 'NW 22nd Ave & NW 36th St',icon=f.Icon(color='purple')).add_to(m2)

# %%
m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m2.save('INTMoreThan10.html')
