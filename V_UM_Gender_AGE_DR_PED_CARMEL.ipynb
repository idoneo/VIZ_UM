# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\cdj49\Desktop\VizUM\2011-2018_Crash_Data.csv')

# %%
df.head()
# Out:
#     CRASHNUM  COUNT  DR_AGE DR_GENDER  VEH_SPEED  Speed_LIMIT  CALYEAR  \
# 0  818743120      1    40.0    Female       35.0         40.0     2011
# 1  817219370      1     NaN       NaN        5.0         35.0     2011
# 2  818746210      1    29.0      Male       10.0         30.0     2011
# 3  817219810      1    58.0      Male       10.0         35.0     2011
# 4  815569390      1    50.0    Female       10.0         25.0     2011
#
#   CRASH_DATE  CRASHTIME DAYOFWEEK         ...                LTCOND Ped_AGE  \
# 0  1/15/2011       1834  Saturday         ...          dark-lighted    60.0
# 1   1/2/2011        921    Sunday         ...              daylight    56.0
# 2  2/18/2011       2345    Friday         ...          dark-lighted    30.0
# 3  1/10/2011       1908    Monday         ...          dark-lighted    43.0
# 4  6/13/2011       1037    Monday         ...              daylight    44.0
#
#    Ped_GENDER CrashYear     Month Holiday   Time Range   LATITUDE  LONGITUDE  \
# ...

# %%
sns.set_style('whitegrid')

# %%
sns.violinplot(x='DR_GENDER',y='DR_AGE',data=df)

plt.title('Driver Age by Gender')
# Out:
# Text(0.5,1,'Driver Age by Gender')

# %%
sns.set_style('whitegrid')

# %%
sns.violinplot(x='Ped_GENDER',y='Ped_AGE',data=df)

plt.title('Pedestrian Age by Gender')
# Out:
# Text(0.5,1,'Pedestrian Age by Gender')

# %%
plt.figure(figsize=(10,6))

# %%
sns.violinplot(x='DR_GENDER',
               y='DR_AGE',
               data=df,
              inner=None,
              palette="Blues")

sns.violinplot(x='Ped_GENDER',
              y='Ped_AGE',
             data=df,
             aplha=0.7)

plt.title('Age by Gender')
# Out:
# Text(0.5,1,'Age by Gender')

# %%
sns.set_style('whitegrid')

# %%
sns.violinplot(x='DR_GENDER',y='VEH_SPEED',data=df)

plt.title('Driver Speed by Gender')
# Out:
# Text(0.5,1,'Driver Speed by Gender')

# %%
plt.figure(figsize=(10,6))

# %%
sns.violinplot(x='Ped_GENDER',
               y='Ped_AGE',
               data=df,
              inner=None,
              palette="Blues")

sns.violinplot(x='DR_GENDER',
              y='DR_AGE',
             data=df,
             aplha=0.7)

plt.title('Age by Gender')
# Out:
# Text(0.5,1,'Age by Gender')
