# %%
import plotly as py
import plotly.graph_objs as go
import ipywidgets as widgets
import numpy as np
import pandas as pd
  
py.offline.init_notebook_mode(connected = True)
import folium as f
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
t_list =['Stamen Terrain','Stamen Toner','Mapbox Bright','cartodbpositron']
miami_center = (25.761681,-80.191788)
m2= f.Map(location=miami_center,
         tiles = 'Stamen Toner',
         zoom_start=11)
f.Marker([25.9408393,-80.2452497], popup = "NW 183rd & NW Miami Gardens DR",icon=f.Icon(color='red')).add_to(m2)
f.Marker([25.8827,-80.166188], popup = "US 1 & Biscayne Blvd",icon=f.Icon(color='red')).add_to(m2)
f.Marker([25.6790288,-80.3172940], popup = "US 1 & S.Dixie Hwy",icon=f.Icon(color='purple')).add_to(m2)
f.Marker([25.754532,-80.222137], popup = "US 1 & SR 5",icon=f.Icon(color='purple')).add_to(m2)
f.Marker([25.8310237,-80.2410341], popup = "NW 27th Ave and SR 9",icon=f.Icon(color='purple')).add_to(m2)
f.Marker([25.7646847,-80.2552132], popup = "SW 8TH ST & Tamimi Trail",icon=f.Icon(color='purple')).add_to(m2)
f.Marker([25.7828841,-80.1311948], popup = "Biscayne Blvd & US 1",icon=f.Icon(color='blue')).add_to(m2)
f.Marker([25.8459779,-80.2416861], popup = "NW 79th & SR 9",icon=f.Icon(color='blue')).add_to(m2)
f.Marker([25.9043356,-80.1591017], popup = "SR5 & Biscayne Blvd",icon=f.Icon(color='blue')).add_to(m2)
f.Marker([25.7952364,-80.2070148], popup = "US 441 & NW 7th Ave",icon=f.Icon(color='blue')).add_to(m2)
m2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m2.save('top_5_Int.HTML')
